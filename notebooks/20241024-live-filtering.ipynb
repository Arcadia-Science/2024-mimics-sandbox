# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
setwd("..")

# %%
virus <- read_tsv("outputs/viruses//foldseek_with_uniprot_metadata/20241018_nomburg_human_viruses_with_uniprot_metadata_filtered.tsv")
# Out:
# Rows: 437 Columns: 237
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (168): query_organism, query, target, human_gene_names_primary, human_fu...
# dbl  (32): qlen, tlen, alnlen, alntmscore, qtmscore, ttmscore, avg_tmscore, ...
# lgl  (37): human_fragment, human_redox_potential, human_temperature_dependen...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
colnames(virus)
# Out:
#   [1] "query_organism"
#   [2] "query"
#   [3] "target"
#   [4] "qlen"
#   [5] "tlen"
#   [6] "alnlen"
#   [7] "alntmscore"
#   [8] "qtmscore"
#   [9] "ttmscore"
#  [10] "avg_tmscore"
#  [11] "min_tmscore"
#  [12] "rank"
#  [13] "human_gene_names_primary"
#  [14] "human_function_cc"
#  [15] "human_tissue_specificity"
#  [16] "human_subcellular_location_cc"
#  [17] "lddt"
#  [18] "lddtfull"
#  [19] "prob"
#  [20] "qcov"
#  [21] "tcov"
#  [22] "pident"
#  [23] "bits"
#  [24] "evalue"
#  [25] "cigar"
#  [26] "qseq"
#  [27] "tseq"
#  [28] "qstart"
#  [29] "qend"
#  [30] "tstart"
#  [31] "tend"
#  [32] "qaln"
#  [33] "taln"
#  [34] "qca"
#  [35] "tca"
#  [36] "u"
#  [37] "t"
#  [38] "human_entry"
#  [39] "human_entry_name"
#  [40] "human_protein_names"
#  [41] "human_annotation"
#  [42] "human_organism"
#  [43] "human_taxonomic_lineage"
#  [44] "human_length"
#  [45] "human_fragment"
#  [46] "human_sequence"
#  [47] "human_reviewed"
#  [48] "human_gene_names"
# ...

# %%
cat(colnames(virus), sep = ", ")
# Out:
# query_organism, query, target, qlen, tlen, alnlen, alntmscore, qtmscore, ttmscore, avg_tmscore, min_tmscore, rank, human_gene_names_primary, human_function_cc, human_tissue_specificity, human_subcellular_location_cc, lddt, lddtfull, prob, qcov, tcov, pident, bits, evalue, cigar, qseq, tseq, qstart, qend, tstart, tend, qaln, taln, qca, tca, u, t, human_entry, human_entry_name, human_protein_names, human_annotation, human_organism, human_taxonomic_lineage, human_length, human_fragment, human_sequence, human_reviewed, human_gene_names, human_protein_existence, human_sequence_version, human_ref_seq, human_gene_id, human_embl, human_alpha_fold_db, human_pdb, human_pfam, human_inter_pro, human_active_site, human_activity_regulation, human_binding_site, human_catalytic_activity, human_cofactor, human_dna_binding, human_ec_number, human_kinetics, human_pathway, human_p_h_dependence, human_redox_potential, human_rhea_id, human_site, human_temperature_dependence, human_fragment_1, human_gene_e
# ...

# %%
virus_tmp <- virus %>%
  select(query_organism, query, target, qlen, tlen, alnlen, alntmscore, qtmscore, ttmscore, avg_tmscore, min_tmscore, pident,
         human_gene_names_primary, human_protein_names, human_function_cc, human_tissue_specificity, human_subcellular_location_cc,
         human_pdb, human_signal_peptide, query_subcellular_location_cc, query_signal_peptide, query_viralzone_genus, query_viralzone_family,
         query_viralzone_primary_tropism, query_viralzone_secondary_tropism)

# %%
write_tsv(virus_tmp, "outputs/viruses/20241024_nomburg_human_viruses_with_uniprot_metadata_filtered.tsv")

# %%
table(is.na(virus$human_pdb))
# Out:
# FALSE  TRUE
#   331   106

# %%
table(is.na(virus$query_pdb))
# Out:
# FALSE  TRUE
#    43   394

# %%
eukaryotes <- read_tsv("outputs/structural_comparison/foldseek_with_uniprot_metadata/20241018_combined_with_uniprot_metadata_filtered.tsv.gz")
# Out:
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details, e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Rows: 12616 Columns: 198
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (129): query_organism, query, target, human_gene_names_primary, human_fu...
# dbl  (28): qlen, tlen, alnlen, alntmscore, qtmscore, ttmscore, avg_tmscore, ...
# lgl  (41): human_fragment, human_redox_potential, human_temperature_dependen...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
colnames(eukaryotes)
# Out:
#   [1] "query_organism"
#   [2] "query"
#   [3] "target"
#   [4] "qlen"
#   [5] "tlen"
#   [6] "alnlen"
#   [7] "alntmscore"
#   [8] "qtmscore"
#   [9] "ttmscore"
#  [10] "avg_tmscore"
#  [11] "min_tmscore"
#  [12] "rank"
#  [13] "human_gene_names_primary"
#  [14] "human_function_cc"
#  [15] "human_tissue_specificity"
#  [16] "human_subcellular_location_cc"
#  [17] "lddt"
#  [18] "lddtfull"
#  [19] "prob"
#  [20] "qcov"
#  [21] "tcov"
#  [22] "pident"
#  [23] "bits"
#  [24] "evalue"
#  [25] "cigar"
#  [26] "qseq"
#  [27] "tseq"
#  [28] "qstart"
#  [29] "qend"
#  [30] "tstart"
#  [31] "tend"
#  [32] "qaln"
#  [33] "taln"
#  [34] "qca"
#  [35] "tca"
#  [36] "u"
#  [37] "t"
#  [38] "human_entry"
#  [39] "human_entry_name"
#  [40] "human_protein_names"
#  [41] "human_annotation"
#  [42] "human_organism"
#  [43] "human_taxonomic_lineage"
#  [44] "human_length"
#  [45] "human_fragment"
#  [46] "human_sequence"
#  [47] "human_reviewed"
#  [48] "human_gene_names"
# ...

# %%
eukaryotes_tmp <- eukaryotes %>%
  select(query_organism, query, target, qlen, tlen, alnlen, alntmscore, qtmscore, ttmscore, avg_tmscore, min_tmscore, pident,
         human_gene_names_primary, human_protein_names, human_function_cc, human_tissue_specificity, human_subcellular_location_cc,
         human_pdb, human_signal_peptide, query_subcellular_location_cc, query_signal_peptide)

# %%
write_tsv(eukaryotes_tmp, "outputs/structural_comparison/foldseek_with_uniprot_metadata/20241024_combined_with_uniprot_metadata_filtered.tsv.gz")

# %%
length(unique(eukaryotes$human_gene_ontology_i_ds))
# Out:
# [1] 3378

# %%
length(unique(virus$human_gene_ontology_i_ds))
# Out:
# [1] 176

# %%
table(is.na(eukaryotes$human_pdb))
# Out:
# FALSE  TRUE
#  6826  5790

# %%
table(is.na(eukaryotes$query_pdb))
# Out:
# FALSE  TRUE
#    39 12577
